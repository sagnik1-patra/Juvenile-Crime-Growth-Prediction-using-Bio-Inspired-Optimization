# %%
import os
import json
import yaml
import joblib
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    accuracy_score,
    classification_report,
    confusion_matrix
)

warnings.filterwarnings("ignore")

BASE_DIR = r"C:\Users\NXTWAVE\Downloads\Juvenile Crime Growth Prediction using Bio-Inspired Optimization"
CSV_PATH = os.path.join(BASE_DIR, "Table_30_1976.csv")

PREFIX = "ais_"
os.makedirs(BASE_DIR, exist_ok=True)

df = pd.read_csv(CSV_PATH)
df.columns = df.columns.str.strip()

for col in df.columns:
    if df[col].dtype == "object":
        df[col] = (
            df[col]
            .astype(str)
            .str.replace(",", "", regex=False)
            .str.replace("%", "", regex=False)
        )
        df[col] = pd.to_numeric(df[col], errors="ignore")

df = df.dropna()

juvenile_col = "Total juvenile crime cases under IPC"

if juvenile_col not in df.columns:
    raise ValueError(f"Column not found: {juvenile_col}")

df["Juvenile Crime Growth Rate"] = df[juvenile_col].pct_change() * 100
df["Juvenile Crime Growth Rate"] = df["Juvenile Crime Growth Rate"].fillna(0)

def classify_growth(value):
    if value < 0:
        return "Decline"
    elif value <= 5:
        return "Low Growth"
    elif value <= 15:
        return "Medium Growth"
    else:
        return "High Growth"

df["Growth Class"] = df["Juvenile Crime Growth Rate"].apply(classify_growth)

classes_csv = os.path.join(BASE_DIR, PREFIX + "classes.csv")
df[["Year", "Juvenile Crime Growth Rate", "Growth Class"]].to_csv(classes_csv, index=False)

X = df.drop(columns=["Juvenile Crime Growth Rate", "Growth Class"])
X = X.select_dtypes(include=[np.number])

y_reg = df["Juvenile Crime Growth Rate"]
y_cls = df["Growth Class"]

feature_names = X.columns.tolist()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# ==================================================
# AIS FEATURE SELECTION
# ==================================================

def fitness_function(mask):
    mask = np.array(mask).astype(bool)

    if mask.sum() == 0:
        return 999999

    X_selected = X_scaled[:, mask]

    X_train, X_test, y_train, y_test = train_test_split(
        X_selected,
        y_reg,
        test_size=0.3,
        random_state=42
    )

    model = RandomForestRegressor(
        n_estimators=100,
        random_state=42
    )

    model.fit(X_train, y_train)
    pred = model.predict(X_test)

    return mean_squared_error(y_test, pred)


def mutate_antibody(antibody, mutation_rate=0.2):
    mutated = antibody.copy()

    for i in range(len(mutated)):
        if np.random.rand() < mutation_rate:
            mutated[i] = 1 - mutated[i]

    return mutated


def ais_feature_selection(
    population_size=20,
    generations=30,
    clone_factor=5,
    mutation_rate=0.2
):
    num_features = X_scaled.shape[1]

    population = np.random.randint(0, 2, (population_size, num_features))

    best_antibody = None
    best_score = float("inf")

    fitness_curve = []

    for generation in range(generations):
        scores = np.array([fitness_function(antibody) for antibody in population])

        sorted_indices = np.argsort(scores)
        population = population[sorted_indices]
        scores = scores[sorted_indices]

        if scores[0] < best_score:
            best_score = scores[0]
            best_antibody = population[0].copy()

        selected_antibodies = population[:population_size // 2]

        clones = []

        for antibody in selected_antibodies:
            for _ in range(clone_factor):
                clone = mutate_antibody(antibody, mutation_rate)
                clones.append(clone)

        clones = np.array(clones)

        clone_scores = np.array([fitness_function(clone) for clone in clones])

        best_clone_indices = np.argsort(clone_scores)[:population_size // 2]
        best_clones = clones[best_clone_indices]

        random_new = np.random.randint(
            0,
            2,
            (population_size - len(best_clones), num_features)
        )

        population = np.vstack((best_clones, random_new))

        fitness_curve.append(best_score)

        print(f"Generation {generation + 1}/{generations} | Best MSE: {best_score}")

    return best_antibody, fitness_curve


best_mask, fitness_curve = ais_feature_selection()

if best_mask.sum() == 0:
    best_mask = np.ones(len(feature_names))

selected_features = [
    feature for feature, selected in zip(feature_names, best_mask)
    if selected == 1
]

X_selected = X_scaled[:, best_mask.astype(bool)]

selected_features_df = pd.DataFrame({
    "Selected Features": selected_features
})

selected_features_df.to_csv(
    os.path.join(BASE_DIR, PREFIX + "selected_features.csv"),
    index=False
)

# ==================================================
# REGRESSION MODEL
# ==================================================

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y_reg,
    test_size=0.3,
    random_state=42
)

reg_model = RandomForestRegressor(
    n_estimators=300,
    random_state=42
)

reg_model.fit(X_train, y_train)
reg_pred = reg_model.predict(X_test)

mae = mean_absolute_error(y_test, reg_pred)
mse = mean_squared_error(y_test, reg_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, reg_pred)

reg_accuracy = max(0, r2) * 100

# ==================================================
# CLASSIFICATION MODEL
# ==================================================

label_encoder = LabelEncoder()
y_cls_encoded = label_encoder.fit_transform(y_cls)

try:
    Xc_train, Xc_test, yc_train, yc_test = train_test_split(
        X_selected,
        y_cls_encoded,
        test_size=0.3,
        random_state=42,
        stratify=y_cls_encoded
    )
except:
    Xc_train, Xc_test, yc_train, yc_test = train_test_split(
        X_selected,
        y_cls_encoded,
        test_size=0.3,
        random_state=42
    )

cls_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

cls_model.fit(Xc_train, yc_train)
cls_pred = cls_model.predict(Xc_test)

class_accuracy = accuracy_score(yc_test, cls_pred) * 100

classification_report_dict = classification_report(
    yc_test,
    cls_pred,
    target_names=label_encoder.classes_,
    output_dict=True,
    zero_division=0
)

cm = confusion_matrix(yc_test, cls_pred)

# ==================================================
# SAVE MODELS
# ==================================================

joblib.dump(reg_model, os.path.join(BASE_DIR, PREFIX + "regression_model.pkl"))
joblib.dump(cls_model, os.path.join(BASE_DIR, PREFIX + "classification_model.pkl"))
joblib.dump(scaler, os.path.join(BASE_DIR, PREFIX + "scaler.pkl"))
joblib.dump(label_encoder, os.path.join(BASE_DIR, PREFIX + "label_encoder.pkl"))

# ==================================================
# SAVE CSV FILES
# ==================================================

prediction_df = pd.DataFrame({
    "Actual Growth Rate": y_test.values,
    "Predicted Growth Rate": reg_pred
})

prediction_csv = os.path.join(BASE_DIR, PREFIX + "prediction.csv")
prediction_df.to_csv(prediction_csv, index=False)

class_prediction_df = pd.DataFrame({
    "Actual Class": label_encoder.inverse_transform(yc_test),
    "Predicted Class": label_encoder.inverse_transform(cls_pred)
})

class_prediction_df.to_csv(
    os.path.join(BASE_DIR, PREFIX + "class_prediction.csv"),
    index=False
)

result_df = pd.DataFrame({
    "Model": [
        "AIS Random Forest Regressor",
        "AIS Random Forest Classifier"
    ],
    "MAE": [mae, np.nan],
    "MSE": [mse, np.nan],
    "RMSE": [rmse, np.nan],
    "R2 Score": [r2, np.nan],
    "Accuracy": [reg_accuracy, class_accuracy]
})

result_csv = os.path.join(BASE_DIR, PREFIX + "result.csv")
result_df.to_csv(result_csv, index=False)

classification_report_df = pd.DataFrame(classification_report_dict).transpose()

classification_report_df.to_csv(
    os.path.join(BASE_DIR, PREFIX + "classification_report.csv")
)

# ==================================================
# SAVE JSON
# ==================================================

summary = {
    "project_name": "Juvenile Crime Growth Prediction using AIS",
    "author": "Sagnik Patra",
    "dataset_path": CSV_PATH,
    "prefix": PREFIX,
    "optimization_algorithm": "Artificial Immune System",
    "selected_features": selected_features,
    "regression_metrics": {
        "MAE": float(mae),
        "MSE": float(mse),
        "RMSE": float(rmse),
        "R2 Score": float(r2),
        "Accuracy": float(reg_accuracy)
    },
    "classification_metrics": {
        "Accuracy": float(class_accuracy),
        "Classes": label_encoder.classes_.tolist()
    }
}

with open(os.path.join(BASE_DIR, PREFIX + "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

# ==================================================
# SAVE YAML
# ==================================================

config = {
    "project": "Juvenile Crime Growth Prediction using AIS",
    "author": "Sagnik Patra",
    "dataset": CSV_PATH,
    "output_directory": BASE_DIR,
    "prefix": PREFIX,
    "target_regression": "Juvenile Crime Growth Rate",
    "target_classification": "Growth Class",
    "optimization_algorithm": "AIS",
    "models": {
        "regression": "RandomForestRegressor",
        "classification": "RandomForestClassifier"
    }
}

with open(os.path.join(BASE_DIR, PREFIX + "config.yaml"), "w") as f:
    yaml.dump(config, f, sort_keys=False)

# ==================================================
# SAVE AND SHOW GRAPHS
# ==================================================

def save_and_show(filename):
    plt.tight_layout()
    plt.savefig(os.path.join(BASE_DIR, filename), dpi=300)
    plt.show()
    plt.close()

# Accuracy graph
plt.figure(figsize=(9, 6))
plt.bar(result_df["Model"], result_df["Accuracy"])
plt.title("AIS Accuracy Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy (%)")
plt.xticks(rotation=20)
save_and_show(PREFIX + "accuracy_graph.png")

# Correlation heatmap
corr = df.select_dtypes(include=[np.number]).corr()

plt.figure(figsize=(12, 8))
plt.imshow(corr, aspect="auto")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("AIS Correlation Heatmap")
save_and_show(PREFIX + "heatmap.png")

# Comparison graph
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, marker="o", label="Actual Growth Rate")
plt.plot(reg_pred, marker="x", label="Predicted Growth Rate")
plt.title("AIS Actual vs Predicted Comparison Graph")
plt.xlabel("Test Sample")
plt.ylabel("Growth Rate")
plt.legend()
plt.grid(True)
save_and_show(PREFIX + "comparison_graph.png")

# Result graph
plt.figure(figsize=(10, 6))
plt.bar(["MAE", "MSE", "RMSE", "R2 Score"], [mae, mse, rmse, r2])
plt.title("AIS Regression Result Graph")
plt.xlabel("Metric")
plt.ylabel("Value")
save_and_show(PREFIX + "result_graph.png")

# Prediction graph
plt.figure(figsize=(10, 6))
plt.plot(prediction_df["Actual Growth Rate"], marker="o", label="Actual")
plt.plot(prediction_df["Predicted Growth Rate"], marker="x", label="Predicted")
plt.title("AIS Prediction Graph")
plt.xlabel("Sample")
plt.ylabel("Juvenile Crime Growth Rate")
plt.legend()
plt.grid(True)
save_and_show(PREFIX + "prediction_graph.png")

# Class graph
class_counts = df["Growth Class"].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(class_counts.index, class_counts.values)
plt.title("AIS Growth Class Graph")
plt.xlabel("Class")
plt.ylabel("Count")
save_and_show(PREFIX + "class_graph.png")

# Confusion matrix heatmap
plt.figure(figsize=(8, 6))
plt.imshow(cm)
plt.colorbar()
plt.title("AIS Confusion Matrix Heatmap")
plt.xticks(range(len(label_encoder.classes_)), label_encoder.classes_, rotation=45)
plt.yticks(range(len(label_encoder.classes_)), label_encoder.classes_)

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
save_and_show(PREFIX + "confusion_matrix_heatmap.png")

# AIS optimization graph
plt.figure(figsize=(10, 6))
plt.plot(fitness_curve, marker="o")
plt.title("AIS Optimization Fitness Graph")
plt.xlabel("Generation")
plt.ylabel("Best MSE")
plt.grid(True)
save_and_show(PREFIX + "optimization_graph.png")

print("\nAll AIS results shown and saved successfully!")

print("\nOutput Folder:")
print(BASE_DIR)

print("\nGenerated Files Prefix:")
print(PREFIX)

print("\nMain Files:")
print(PREFIX + "regression_model.pkl")
print(PREFIX + "classification_model.pkl")
print(PREFIX + "scaler.pkl")
print(PREFIX + "label_encoder.pkl")
print(PREFIX + "summary.json")
print(PREFIX + "config.yaml")
print(PREFIX + "result.csv")
print(PREFIX + "prediction.csv")
print(PREFIX + "classes.csv")
print(PREFIX + "class_prediction.csv")
print(PREFIX + "selected_features.csv")
print(PREFIX + "accuracy_graph.png")
print(PREFIX + "heatmap.png")
print(PREFIX + "comparison_graph.png")
print(PREFIX + "result_graph.png")
print(PREFIX + "prediction_graph.png")
print(PREFIX + "class_graph.png")
print(PREFIX + "confusion_matrix_heatmap.png")
print(PREFIX + "optimization_graph.png")
# Out:
# Generation 1/30 | Best MSE: 85.95217562919699
# Generation 2/30 | Best MSE: 84.86855420414953
# Generation 3/30 | Best MSE: 84.60394348899739
# Generation 4/30 | Best MSE: 84.60394348899739
# Generation 5/30 | Best MSE: 84.60394348899739
# Generation 6/30 | Best MSE: 84.60394348899739
# Generation 7/30 | Best MSE: 84.60394348899739
# Generation 8/30 | Best MSE: 84.60394348899739
# Generation 9/30 | Best MSE: 84.60394348899739
# Generation 10/30 | Best MSE: 84.60394348899739
# Generation 11/30 | Best MSE: 84.60394348899739
# Generation 12/30 | Best MSE: 84.60394348899739
# Generation 13/30 | Best MSE: 84.60394348899739
# Generation 14/30 | Best MSE: 84.60394348899739
# Generation 15/30 | Best MSE: 84.60394348899739
# Generation 16/30 | Best MSE: 84.60394348899739
# Generation 17/30 | Best MSE: 84.60394348899739
# Generation 18/30 | Best MSE: 84.60394348899739
# Generation 19/30 | Best MSE: 84.60394348899739
# Generation 20/30 | Best MSE: 84.60394348899739
# Generation 21/30 | Best MSE: 84.60394348899739
# Generation 22/30 | Best MSE: 84.60394348899739
# Generation 23/30 | Best MSE: 84.60394348899739
# Generation 24/30 | Best MSE: 84.60394348899739
# Generation 25/30 | Best MSE: 84.60394348899739
# Generation 26/30 | Best MSE: 84.60394348899739
# Generation 27/30 | Best MSE: 84.60394348899739
# Generation 28/30 | Best MSE: 84.60394348899739
# Generation 29/30 | Best MSE: 84.60394348899739
# Generation 30/30 | Best MSE: 84.60394348899739
# All AIS results shown and saved successfully!
#
# Output Folder:
# C:\Users\NXTWAVE\Downloads\Juvenile Crime Growth Prediction using Bio-Inspired Optimization
#
# Generated Files Prefix:
# ais_
#
# Main Files:
# ais_regression_model.pkl
# ais_classification_model.pkl
# ais_scaler.pkl
# ais_label_encoder.pkl
# ais_summary.json
# ais_config.yaml
# ais_result.csv
# ais_prediction.csv
# ais_classes.csv
# ais_class_prediction.csv
# ais_selected_features.csv
# ais_accuracy_graph.png
# ais_heatmap.png
# ais_comparison_graph.png
# ais_result_graph.png
# ais_prediction_graph.png
# ais_class_graph.png
# ais_confusion_matrix_heatmap.png
# ais_optimization_graph.png
